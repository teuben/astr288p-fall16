# %% [markdown]
# # Arrays for Numerical work?

# %%
a = [1,2,3]
b = [4,5,6]
c = a+b
print(c)

# %% [markdown]
# You can see, adding two lists just results in a longer list, catenation of the two.

# %%
a.append(b)
print(a)

# %%
def sum(data):
    """ sum the elements of an array
    """
    asum = 0.0
    for i in data:
        asum = asum + i
    return asum

# %%
# the length of the array is defined here, and re-used below

n = 10000000

# %%
# %%time
a = list(range(n))

# %%
# %%time
print(sum(a))

# %%
import numpy as np

# %%
# %%time
a=np.arange(n)

# %%
# %%time
print(a.sum())

# %%
a=np.arange(10)
b=np.arange(10)
c = a + b
d = 3*a*a + b + 2.0
print(c)
print(d)

# %%
c.shape

# %%
c2=c.reshape(5,2)

# %%
print(c)
print(c2)

# %%
c[0]=999

# %%
print(c2)

# %%
d2=c.reshape(5,2)[1:3,:]

# %%
print(d2)

# %%
d2[1,1]=888

# %%
print(c)

# %%
print(c2)

# %% [markdown]
# Finally, this notebook can also be saved in python, and run through ipython (*or python if no cell_magic was used*).
